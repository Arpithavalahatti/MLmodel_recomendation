# %%
# !pip install pycaret
# Out:
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\anakonda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\anakonda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\anakonda\lib\site-packages)
#   Using cached pycaret-3.0.3-py3-none-any.whl (484 kB)
# ...
#   Using cached sktime-0.20.0-py3-none-any.whl (17.0 MB)
# ...
#   Using cached lightgbm-3.3.5-py3-none-win_amd64.whl (1.0 MB)
# ...
#   Using cached pmdarima-2.0.3-cp39-cp39-win_amd64.whl (572 kB)
# ...
#   Using cached psutil-5.9.5-cp36-abi3-win_amd64.whl (255 kB)
# ...
#   Using cached xxhash-3.2.0-cp39-cp39-win_amd64.whl (30 kB)
# ...
#   Using cached plotly_resampler-0.8.3.2-cp39-cp39-win_amd64.whl
# ...
#   Using cached scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# ...
#   Using cached numba-0.57.1-cp39-cp39-win_amd64.whl (2.5 MB)
# ...
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# ...
#   Using cached category_encoders-2.6.1-py2.py3-none-any.whl (81 kB)
# ...

# %%
# !pip install --upgrade --force-reinstall scikit-learn llvmlite
# Out:
# ...
#   Using cached scikit_learn-1.3.0-cp39-cp39-win_amd64.whl (9.3 MB)
# ...
#   Using cached llvmlite-0.40.1-cp39-cp39-win_amd64.whl (27.7 MB)
# ...
#   Using cached joblib-1.3.1-py3-none-any.whl (301 kB)
# ...
#   Using cached numpy-1.25.0-cp39-cp39-win_amd64.whl (15.1 MB)
# ...
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
# WARNING: Ignoring invalid distribution -rotobuf (c:\anakonda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\anakonda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\anakonda\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\anakonda\lib\site-packages)
# ...

# %%
# !pip install --upgrade --force-reinstall protobuf
# Out:
# ...
#   Using cached protobuf-4.23.3-cp39-cp39-win_amd64.whl (422 kB)
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.23.3
#     Uninstalling protobuf-4.23.3:
#       Successfully uninstalled protobuf-4.23.3
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\anakonda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\anakonda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\anakonda\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\anakonda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\anakonda\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-gpu 2.9.1 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.23.3 which is incompatible.
# ...

# %%
# !pip install streamlit
# Out:
# ...
#   Using cached Pygments-2.15.1-py3-none-any.whl (1.1 MB)
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\anakonda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\anakonda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\anakonda\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\anakonda\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\anakonda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\anakonda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\anakonda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\anakonda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\anakonda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\anakonda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\anakonda\lib\site-packages)
# ...
